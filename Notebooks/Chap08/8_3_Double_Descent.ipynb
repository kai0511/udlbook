# %% [markdown]
# <a href="https://colab.research.google.com/github/kai0511/udlbook/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-m7kd5zve
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-m7kd5zve
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (2.32.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (1.15.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.4.26)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=ba9054e7c46680649d3d795681b8e3b8a3c82538337d9c3f4021d6d41aa2c584
#   Stored in directory: /tmp/pip-ephem-wheel-cache-o7qhlml5/wheels/d6/38/42/3d2112bc7d915f6195254ac85eb761d922d1b18f52817aa8e2
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.304616, train error 89.20,  test loss 2.297315, test error 88.40
# Epoch   100, train loss 1.919238, train error 72.97,  test loss 1.755504, test error 70.38
# Epoch   200, train loss 1.916487, train error 72.03,  test loss 1.745812, test error 69.03
# Epoch   300, train loss 1.908680, train error 71.97,  test loss 1.737160, test error 68.93
# Epoch   400, train loss 1.908306, train error 71.53,  test loss 1.737967, test error 69.97
# Epoch   500, train loss 1.907650, train error 70.78,  test loss 1.742062, test error 70.00
# Epoch   600, train loss 1.909084, train error 71.88,  test loss 1.740036, test error 69.78
# Epoch   700, train loss 1.906076, train error 71.30,  test loss 1.732777, test error 69.05
# Epoch   800, train loss 1.906971, train error 71.25,  test loss 1.731524, test error 69.53
# Epoch   900, train loss 1.905480, train error 71.72,  test loss 1.733241, test error 69.15
# Training model with   4 hidden variables
# Epoch     0, train loss 2.258333, train error 86.03,  test loss 2.252794, test error 85.00
# Epoch   100, train loss 1.758741, train error 64.93,  test loss 1.596242, test error 61.38
# Epoch   200, train loss 1.741458, train error 62.90,  test loss 1.564860, test error 59.80
# Epoch   300, train loss 1.731452, train error 63.65,  test loss 1.552790, test error 59.80
# Epoch   400, train loss 1.728838, train error 64.38,  test loss 1.553999, test error 60.30
# Epoch   500, train loss 1.725453, train error 63.47,  test loss 1.545358, test error 59.70
# Epoch   600, train loss 1.724776, train error 64.03,  test loss 1.553596, test error 60.10
# Epoch   700, train loss 1.723654, train error 63.67,  test loss 1.546611, test error 59.78
# Epoch   800, train loss 1.723168, train error 63.38,  test loss 1.547268, test error 59.67
# Epoch   900, train loss 1.724758, train error 63.42,  test loss 1.549400, test error 60.08
# Training model with   6 hidden variables
# Epoch     0, train loss 2.260580, train error 85.80,  test loss 2.258496, test error 86.85
# Epoch   100, train loss 1.692269, train error 61.30,  test loss 1.507282, test error 57.33
# Epoch   200, train loss 1.671837, train error 59.53,  test loss 1.500548, test error 57.00
# Epoch   300, train loss 1.664414, train error 59.00,  test loss 1.505525, test error 56.65
# Epoch   400, train loss 1.658924, train error 58.88,  test loss 1.501260, test error 57.15
# Epoch   500, train loss 1.656595, train error 58.58,  test loss 1.515022, test error 57.33
# Epoch   600, train loss 1.651258, train error 59.58,  test loss 1.512794, test error 58.20
# Epoch   700, train loss 1.649562, train error 59.03,  test loss 1.521607, test error 58.30
# Epoch   800, train loss 1.647958, train error 58.90,  test loss 1.523605, test error 58.88
# Epoch   900, train loss 1.643916, train error 59.55,  test loss 1.537283, test error 57.90
# Training model with   8 hidden variables
# Epoch     0, train loss 2.274808, train error 84.55,  test loss 2.259420, test error 84.15
# Epoch   100, train loss 1.602957, train error 57.05,  test loss 1.468102, test error 56.20
# Epoch   200, train loss 1.546587, train error 53.97,  test loss 1.418270, test error 54.58
# Epoch   300, train loss 1.524512, train error 53.42,  test loss 1.398841, test error 53.12
# Epoch   400, train loss 1.516037, train error 53.03,  test loss 1.409893, test error 53.17
# Epoch   500, train loss 1.512074, train error 52.72,  test loss 1.410936, test error 53.53
# Epoch   600, train loss 1.514991, train error 52.97,  test loss 1.411380, test error 54.15
# Epoch   700, train loss 1.506015, train error 52.58,  test loss 1.415919, test error 53.65
# Epoch   800, train loss 1.505489, train error 52.58,  test loss 1.422544, test error 54.10
# Epoch   900, train loss 1.503913, train error 51.92,  test loss 1.420167, test error 53.85
# Training model with  10 hidden variables
# Epoch     0, train loss 2.199129, train error 81.28,  test loss 2.173749, test error 80.93
# Epoch   100, train loss 1.553364, train error 53.25,  test loss 1.422829, test error 53.33
# Epoch   200, train loss 1.450632, train error 48.53,  test loss 1.304268, test error 48.53
# Epoch   300, train loss 1.410008, train error 47.50,  test loss 1.289162, test error 47.78
# Epoch   400, train loss 1.396477, train error 46.85,  test loss 1.278567, test error 46.80
# Epoch   500, train loss 1.387213, train error 46.70,  test loss 1.283853, test error 46.88
# Epoch   600, train loss 1.384491, train error 45.85,  test loss 1.287393, test error 46.42
# Epoch   700, train loss 1.387170, train error 46.80,  test loss 1.289039, test error 46.92
# Epoch   800, train loss 1.376060, train error 45.53,  test loss 1.283798, test error 46.53
# Epoch   900, train loss 1.379942, train error 46.62,  test loss 1.295811, test error 46.50
# Training model with  14 hidden variables
# Epoch     0, train loss 2.267758, train error 83.90,  test loss 2.266466, test error 83.78
# Epoch   100, train loss 1.487858, train error 51.72,  test loss 1.410831, test error 53.85
# Epoch   200, train loss 1.375836, train error 47.30,  test loss 1.360876, test error 51.00
# Epoch   300, train loss 1.331172, train error 45.08,  test loss 1.351485, test error 49.95
# Epoch   400, train loss 1.314339, train error 44.78,  test loss 1.355163, test error 49.80
# Epoch   500, train loss 1.282496, train error 43.22,  test loss 1.355756, test error 49.08
# Epoch   600, train loss 1.274121, train error 42.88,  test loss 1.376135, test error 49.95
# Epoch   700, train loss 1.272524, train error 43.05,  test loss 1.389995, test error 49.80
# Epoch   800, train loss 1.265605, train error 43.33,  test loss 1.411987, test error 50.83
# Epoch   900, train loss 1.252173, train error 42.22,  test loss 1.427812, test error 50.40
# Training model with  18 hidden variables
# Epoch     0, train loss 2.191405, train error 81.88,  test loss 2.170552, test error 81.55
# Epoch   100, train loss 1.313769, train error 44.15,  test loss 1.268658, test error 47.80
# Epoch   200, train loss 1.232247, train error 41.83,  test loss 1.311469, test error 48.88
# Epoch   300, train loss 1.190609, train error 41.05,  test loss 1.347029, test error 48.60
# Epoch   400, train loss 1.149510, train error 38.55,  test loss 1.374380, test error 49.15
# Epoch   500, train loss 1.140066, train error 38.70,  test loss 1.432780, test error 50.50
# Epoch   600, train loss 1.121771, train error 38.25,  test loss 1.456859, test error 50.08
# Epoch   700, train loss 1.108553, train error 38.10,  test loss 1.475164, test error 50.30
# Epoch   800, train loss 1.106268, train error 37.80,  test loss 1.476550, test error 50.10
# Epoch   900, train loss 1.107588, train error 38.12,  test loss 1.477592, test error 50.25
# Training model with  22 hidden variables
# Epoch     0, train loss 2.230879, train error 82.43,  test loss 2.212396, test error 81.62
# Epoch   100, train loss 1.269068, train error 41.17,  test loss 1.262914, test error 46.80
# Epoch   200, train loss 1.166531, train error 37.70,  test loss 1.346872, test error 48.88
# Epoch   300, train loss 1.104896, train error 36.03,  test loss 1.408515, test error 49.53
# Epoch   400, train loss 1.068614, train error 35.30,  test loss 1.477786, test error 50.33
# Epoch   500, train loss 1.047959, train error 34.22,  test loss 1.508070, test error 50.85
# Epoch   600, train loss 1.021054, train error 33.22,  test loss 1.557661, test error 50.83
# Epoch   700, train loss 1.007041, train error 32.18,  test loss 1.573183, test error 50.00
# Epoch   800, train loss 1.017258, train error 33.93,  test loss 1.629689, test error 51.30
# Epoch   900, train loss 0.988838, train error 31.45,  test loss 1.647615, test error 51.90
# Training model with  26 hidden variables
# Epoch     0, train loss 2.185584, train error 81.07,  test loss 2.157575, test error 80.25
# Epoch   100, train loss 1.199741, train error 40.03,  test loss 1.383033, test error 50.60
# Epoch   200, train loss 1.078292, train error 36.72,  test loss 1.532831, test error 52.25
# Epoch   300, train loss 0.986716, train error 33.97,  test loss 1.595021, test error 52.95
# Epoch   400, train loss 0.933560, train error 32.05,  test loss 1.715582, test error 52.90
# Epoch   500, train loss 0.913628, train error 32.22,  test loss 1.816552, test error 52.83
# Epoch   600, train loss 0.897342, train error 31.85,  test loss 1.906463, test error 53.95
# Epoch   700, train loss 0.865862, train error 29.75,  test loss 2.001664, test error 54.30
# Epoch   800, train loss 0.837048, train error 28.88,  test loss 2.051887, test error 53.95
# Epoch   900, train loss 0.842145, train error 29.80,  test loss 2.106299, test error 54.38
# Training model with  30 hidden variables
# Epoch     0, train loss 2.152360, train error 78.47,  test loss 2.116228, test error 77.78
# Epoch   100, train loss 1.108942, train error 36.25,  test loss 1.336591, test error 48.38
# Epoch   200, train loss 0.934286, train error 30.32,  test loss 1.503152, test error 50.80
# Epoch   300, train loss 0.851408, train error 28.32,  test loss 1.703395, test error 51.75
# Epoch   400, train loss 0.805668, train error 26.43,  test loss 1.831441, test error 52.40
# Epoch   500, train loss 0.773599, train error 25.97,  test loss 1.965580, test error 53.62
# Epoch   600, train loss 0.745856, train error 25.32,  test loss 2.111373, test error 53.95
# Epoch   700, train loss 0.730430, train error 24.88,  test loss 2.233580, test error 53.85
# Epoch   800, train loss 0.703987, train error 24.45,  test loss 2.316033, test error 54.62
# Epoch   900, train loss 0.691794, train error 24.18,  test loss 2.396932, test error 54.95
# Training model with  35 hidden variables
# Epoch     0, train loss 2.104879, train error 77.53,  test loss 2.050688, test error 76.72
# Epoch   100, train loss 1.015386, train error 33.70,  test loss 1.385147, test error 49.75
# Epoch   200, train loss 0.791016, train error 25.82,  test loss 1.705780, test error 52.53
# Epoch   300, train loss 0.672632, train error 21.80,  test loss 1.969816, test error 53.50
# Epoch   400, train loss 0.601686, train error 20.65,  test loss 2.352898, test error 54.83
# Epoch   500, train loss 0.527194, train error 18.25,  test loss 2.732967, test error 55.92
# Epoch   600, train loss 0.495148, train error 17.18,  test loss 3.097912, test error 56.62
# Epoch   700, train loss 0.505740, train error 18.38,  test loss 3.485556, test error 57.47
# Epoch   800, train loss 0.443129, train error 15.00,  test loss 3.664688, test error 56.62
# Epoch   900, train loss 0.418408, train error 14.18,  test loss 4.019951, test error 57.42
# Training model with  40 hidden variables
# Epoch     0, train loss 2.152080, train error 80.05,  test loss 2.108279, test error 78.72
# Epoch   100, train loss 0.922331, train error 29.03,  test loss 1.458638, test error 49.65
# Epoch   200, train loss 0.623112, train error 19.62,  test loss 2.000663, test error 53.05
# Epoch   300, train loss 0.485282, train error 15.57,  test loss 2.705380, test error 54.55
# Epoch   400, train loss 0.379521, train error 12.18,  test loss 3.396149, test error 55.40
# Epoch   500, train loss 0.321501, train error 10.20,  test loss 4.116972, test error 56.62
# Epoch   600, train loss 0.298667, train error 9.82,  test loss 4.886665, test error 56.50
# Epoch   700, train loss 0.260221, train error 9.53,  test loss 5.725316, test error 57.90
# Epoch   800, train loss 0.263434, train error 8.88,  test loss 6.479814, test error 57.47
# Epoch   900, train loss 0.262041, train error 9.57,  test loss 7.221231, test error 58.62
# Training model with  45 hidden variables
# Epoch     0, train loss 2.085103, train error 78.80,  test loss 2.013047, test error 78.22
# Epoch   100, train loss 0.840745, train error 27.05,  test loss 1.478626, test error 49.97
# Epoch   200, train loss 0.506622, train error 15.25,  test loss 2.252970, test error 54.38
# Epoch   300, train loss 0.358539, train error 11.65,  test loss 3.336817, test error 56.33
# Epoch   400, train loss 0.203777, train error 6.10,  test loss 4.568574, test error 56.00
# Epoch   500, train loss 0.147494, train error 4.15,  test loss 5.945117, test error 55.72
# Epoch   600, train loss 0.172901, train error 5.57,  test loss 7.181147, test error 56.10
# Epoch   700, train loss 0.015099, train error 0.03,  test loss 8.268216, test error 56.50
# Epoch   800, train loss 0.008462, train error 0.00,  test loss 9.036699, test error 56.50
# Epoch   900, train loss 0.006143, train error 0.00,  test loss 9.568031, test error 56.33
# Training model with  50 hidden variables
# Epoch     0, train loss 2.095783, train error 77.78,  test loss 2.065171, test error 77.95
# Epoch   100, train loss 0.713645, train error 22.28,  test loss 1.548936, test error 50.53
# Epoch   200, train loss 0.345021, train error 10.03,  test loss 2.561429, test error 52.85
# Epoch   300, train loss 0.134461, train error 2.47,  test loss 4.178438, test error 54.85
# Epoch   400, train loss 0.034057, train error 0.03,  test loss 5.854302, test error 56.00
# Epoch   500, train loss 0.015059, train error 0.00,  test loss 6.895886, test error 56.33
# Epoch   600, train loss 0.009444, train error 0.00,  test loss 7.597078, test error 56.38
# Epoch   700, train loss 0.006705, train error 0.00,  test loss 8.114088, test error 56.25
# Epoch   800, train loss 0.005115, train error 0.00,  test loss 8.519910, test error 56.40
# Epoch   900, train loss 0.004091, train error 0.00,  test loss 8.863149, test error 56.42
# Training model with  55 hidden variables
# Epoch     0, train loss 2.059317, train error 76.75,  test loss 2.019946, test error 76.10
# Epoch   100, train loss 0.640548, train error 19.82,  test loss 1.581524, test error 49.35
# Epoch   200, train loss 0.235540, train error 6.10,  test loss 2.818232, test error 51.90
# Epoch   300, train loss 0.048870, train error 0.10,  test loss 4.493642, test error 53.60
# Epoch   400, train loss 0.016183, train error 0.00,  test loss 5.533866, test error 52.90
# Epoch   500, train loss 0.009278, train error 0.00,  test loss 6.179886, test error 53.08
# Epoch   600, train loss 0.006319, train error 0.00,  test loss 6.642167, test error 53.35
# Epoch   700, train loss 0.004682, train error 0.00,  test loss 6.995670, test error 53.42
# Epoch   800, train loss 0.003682, train error 0.00,  test loss 7.275995, test error 53.47
# Epoch   900, train loss 0.002997, train error 0.00,  test loss 7.525997, test error 53.50
# Training model with  60 hidden variables
# Epoch     0, train loss 2.082440, train error 77.20,  test loss 2.057081, test error 78.15
# Epoch   100, train loss 0.551457, train error 16.00,  test loss 1.762703, test error 51.80
# Epoch   200, train loss 0.101483, train error 0.72,  test loss 3.429243, test error 54.03
# Epoch   300, train loss 0.019725, train error 0.00,  test loss 4.807149, test error 54.47
# Epoch   400, train loss 0.009519, train error 0.00,  test loss 5.530994, test error 54.78
# Epoch   500, train loss 0.005928, train error 0.00,  test loss 5.982083, test error 55.08
# Epoch   600, train loss 0.004254, train error 0.00,  test loss 6.320527, test error 54.88
# Epoch   700, train loss 0.003273, train error 0.00,  test loss 6.592452, test error 55.15
# Epoch   800, train loss 0.002619, train error 0.00,  test loss 6.809269, test error 54.97
# Epoch   900, train loss 0.002174, train error 0.00,  test loss 6.996971, test error 55.08
# Training model with  70 hidden variables
# Epoch     0, train loss 2.001240, train error 73.90,  test loss 1.938829, test error 75.00
# Epoch   100, train loss 0.379069, train error 10.07,  test loss 1.904763, test error 51.33
# Epoch   200, train loss 0.037854, train error 0.00,  test loss 3.565053, test error 53.10
# Epoch   300, train loss 0.011954, train error 0.00,  test loss 4.402181, test error 53.45
# Epoch   400, train loss 0.006573, train error 0.00,  test loss 4.870888, test error 53.45
# Epoch   500, train loss 0.004370, train error 0.00,  test loss 5.196365, test error 53.53
# Epoch   600, train loss 0.003220, train error 0.00,  test loss 5.442475, test error 53.78
# Epoch   700, train loss 0.002517, train error 0.00,  test loss 5.647916, test error 53.72
# Epoch   800, train loss 0.002048, train error 0.00,  test loss 5.811707, test error 53.70
# Epoch   900, train loss 0.001719, train error 0.00,  test loss 5.953560, test error 53.85
# Training model with  80 hidden variables
# Epoch     0, train loss 2.008486, train error 74.85,  test loss 1.961649, test error 76.55
# Epoch   100, train loss 0.243221, train error 4.10,  test loss 2.034485, test error 50.72
# Epoch   200, train loss 0.020545, train error 0.00,  test loss 3.398598, test error 51.45
# Epoch   300, train loss 0.008167, train error 0.00,  test loss 3.956078, test error 51.78
# Epoch   400, train loss 0.004841, train error 0.00,  test loss 4.281221, test error 51.67
# Epoch   500, train loss 0.003310, train error 0.00,  test loss 4.518917, test error 51.80
# Epoch   600, train loss 0.002498, train error 0.00,  test loss 4.700756, test error 51.97
# Epoch   700, train loss 0.001981, train error 0.00,  test loss 4.848577, test error 51.90
# Epoch   800, train loss 0.001631, train error 0.00,  test loss 4.972869, test error 51.92
# Epoch   900, train loss 0.001380, train error 0.00,  test loss 5.080805, test error 51.92
# Training model with  90 hidden variables
# Epoch     0, train loss 1.988585, train error 74.22,  test loss 1.921684, test error 74.82
# Epoch   100, train loss 0.130656, train error 1.05,  test loss 2.253348, test error 52.10
# Epoch   200, train loss 0.013989, train error 0.00,  test loss 3.284576, test error 51.65
# Epoch   300, train loss 0.006225, train error 0.00,  test loss 3.702622, test error 51.60
# Epoch   400, train loss 0.003827, train error 0.00,  test loss 3.957765, test error 51.72
# Epoch   500, train loss 0.002698, train error 0.00,  test loss 4.142525, test error 51.75
# Epoch   600, train loss 0.002059, train error 0.00,  test loss 4.286515, test error 51.67
# Epoch   700, train loss 0.001651, train error 0.00,  test loss 4.403591, test error 51.70
# Epoch   800, train loss 0.001368, train error 0.00,  test loss 4.503989, test error 51.65
# Epoch   900, train loss 0.001163, train error 0.00,  test loss 4.590866, test error 51.65
# Training model with 100 hidden variables
# Epoch     0, train loss 1.991588, train error 74.65,  test loss 1.925327, test error 73.53
# Epoch   100, train loss 0.119496, train error 0.50,  test loss 2.219347, test error 51.60
# Epoch   200, train loss 0.013619, train error 0.00,  test loss 3.157447, test error 51.53
# Epoch   300, train loss 0.006171, train error 0.00,  test loss 3.557549, test error 51.70
# Epoch   400, train loss 0.003790, train error 0.00,  test loss 3.806915, test error 52.05
# Epoch   500, train loss 0.002683, train error 0.00,  test loss 3.987008, test error 52.20
# Epoch   600, train loss 0.002050, train error 0.00,  test loss 4.127755, test error 52.12
# Epoch   700, train loss 0.001645, train error 0.00,  test loss 4.244320, test error 52.12
# Epoch   800, train loss 0.001364, train error 0.00,  test loss 4.341812, test error 52.20
# Epoch   900, train loss 0.001160, train error 0.00,  test loss 4.428226, test error 52.15
# Training model with 120 hidden variables
# Epoch     0, train loss 1.984633, train error 74.05,  test loss 1.908477, test error 74.20
# Epoch   100, train loss 0.049734, train error 0.00,  test loss 2.156214, test error 49.53
# Epoch   200, train loss 0.009426, train error 0.00,  test loss 2.757438, test error 49.12
# Epoch   300, train loss 0.004653, train error 0.00,  test loss 3.028156, test error 49.50
# Epoch   400, train loss 0.002986, train error 0.00,  test loss 3.202739, test error 49.50
# Epoch   500, train loss 0.002151, train error 0.00,  test loss 3.332300, test error 49.55
# Epoch   600, train loss 0.001662, train error 0.00,  test loss 3.434161, test error 49.47
# Epoch   700, train loss 0.001344, train error 0.00,  test loss 3.519165, test error 49.55
# Epoch   800, train loss 0.001122, train error 0.00,  test loss 3.592129, test error 49.62
# Epoch   900, train loss 0.000959, train error 0.00,  test loss 3.654416, test error 49.60
# Training model with 140 hidden variables
# Epoch     0, train loss 1.933309, train error 71.70,  test loss 1.853125, test error 72.47
# Epoch   100, train loss 0.035607, train error 0.00,  test loss 2.233915, test error 49.80
# Epoch   200, train loss 0.008052, train error 0.00,  test loss 2.738918, test error 50.20
# Epoch   300, train loss 0.004134, train error 0.00,  test loss 2.979503, test error 50.05
# Epoch   400, train loss 0.002689, train error 0.00,  test loss 3.137938, test error 50.30
# Epoch   500, train loss 0.001955, train error 0.00,  test loss 3.254104, test error 50.33
# Epoch   600, train loss 0.001520, train error 0.00,  test loss 3.347125, test error 50.40
# Epoch   700, train loss 0.001235, train error 0.00,  test loss 3.423772, test error 50.40
# Epoch   800, train loss 0.001034, train error 0.00,  test loss 3.489319, test error 50.47
# Epoch   900, train loss 0.000886, train error 0.00,  test loss 3.546970, test error 50.42
# Training model with 160 hidden variables
# Epoch     0, train loss 1.967897, train error 73.00,  test loss 1.907711, test error 73.03
# Epoch   100, train loss 0.029110, train error 0.00,  test loss 2.129325, test error 49.42
# Epoch   200, train loss 0.007198, train error 0.00,  test loss 2.528332, test error 49.42
# Epoch   300, train loss 0.003785, train error 0.00,  test loss 2.727057, test error 49.60
# Epoch   400, train loss 0.002488, train error 0.00,  test loss 2.859914, test error 49.90
# Epoch   500, train loss 0.001821, train error 0.00,  test loss 2.957782, test error 49.78
# Epoch   600, train loss 0.001421, train error 0.00,  test loss 3.037122, test error 49.75
# Epoch   700, train loss 0.001157, train error 0.00,  test loss 3.103276, test error 49.58
# Epoch   800, train loss 0.000972, train error 0.00,  test loss 3.159764, test error 49.53
# Epoch   900, train loss 0.000834, train error 0.00,  test loss 3.209303, test error 49.50
# Training model with 180 hidden variables
# Epoch     0, train loss 1.916352, train error 70.10,  test loss 1.850770, test error 72.35
# Epoch   100, train loss 0.024358, train error 0.00,  test loss 2.041426, test error 48.22
# Epoch   200, train loss 0.006584, train error 0.00,  test loss 2.403199, test error 48.22
# Epoch   300, train loss 0.003522, train error 0.00,  test loss 2.583766, test error 48.38
# Epoch   400, train loss 0.002329, train error 0.00,  test loss 2.705530, test error 48.47
# Epoch   500, train loss 0.001714, train error 0.00,  test loss 2.797248, test error 48.53
# Epoch   600, train loss 0.001342, train error 0.00,  test loss 2.870917, test error 48.65
# Epoch   700, train loss 0.001095, train error 0.00,  test loss 2.931273, test error 48.67
# Epoch   800, train loss 0.000921, train error 0.00,  test loss 2.984057, test error 48.72
# Epoch   900, train loss 0.000791, train error 0.00,  test loss 3.029468, test error 48.60
# Training model with 200 hidden variables
# Epoch     0, train loss 1.935640, train error 72.22,  test loss 1.849832, test error 72.40
# Epoch   100, train loss 0.021856, train error 0.00,  test loss 1.964394, test error 47.90
# Epoch   200, train loss 0.006093, train error 0.00,  test loss 2.263695, test error 47.55
# Epoch   300, train loss 0.003314, train error 0.00,  test loss 2.419616, test error 47.30
# Epoch   400, train loss 0.002209, train error 0.00,  test loss 2.524767, test error 47.28
# Epoch   500, train loss 0.001633, train error 0.00,  test loss 2.604222, test error 47.22
# Epoch   600, train loss 0.001283, train error 0.00,  test loss 2.667923, test error 47.25
# Epoch   700, train loss 0.001050, train error 0.00,  test loss 2.721854, test error 47.17
# Epoch   800, train loss 0.000884, train error 0.00,  test loss 2.767305, test error 47.12
# Epoch   900, train loss 0.000761, train error 0.00,  test loss 2.806423, test error 47.08
# Training model with 250 hidden variables
# Epoch     0, train loss 1.887424, train error 68.90,  test loss 1.804068, test error 69.62
# Epoch   100, train loss 0.016760, train error 0.00,  test loss 1.926757, test error 47.83
# Epoch   200, train loss 0.005322, train error 0.00,  test loss 2.185796, test error 47.53
# Epoch   300, train loss 0.002973, train error 0.00,  test loss 2.323174, test error 47.42
# Epoch   400, train loss 0.002010, train error 0.00,  test loss 2.418072, test error 47.45
# Epoch   500, train loss 0.001495, train error 0.00,  test loss 2.488594, test error 47.42
# Epoch   600, train loss 0.001181, train error 0.00,  test loss 2.545477, test error 47.40
# Epoch   700, train loss 0.000969, train error 0.00,  test loss 2.593370, test error 47.40
# Epoch   800, train loss 0.000819, train error 0.00,  test loss 2.634866, test error 47.42
# Epoch   900, train loss 0.000706, train error 0.00,  test loss 2.670693, test error 47.50
# Training model with 300 hidden variables
# Epoch     0, train loss 1.877360, train error 67.57,  test loss 1.793587, test error 70.18
# Epoch   100, train loss 0.014637, train error 0.00,  test loss 1.868588, test error 46.47
# Epoch   200, train loss 0.004848, train error 0.00,  test loss 2.083934, test error 46.17
# Epoch   300, train loss 0.002735, train error 0.00,  test loss 2.197867, test error 46.30
# Epoch   400, train loss 0.001862, train error 0.00,  test loss 2.277159, test error 46.30
# Epoch   500, train loss 0.001393, train error 0.00,  test loss 2.338372, test error 46.38
# Epoch   600, train loss 0.001104, train error 0.00,  test loss 2.387362, test error 46.30
# Epoch   700, train loss 0.000909, train error 0.00,  test loss 2.428488, test error 46.17
# Epoch   800, train loss 0.000769, train error 0.00,  test loss 2.463865, test error 46.15
# Epoch   900, train loss 0.000665, train error 0.00,  test loss 2.495517, test error 46.10
# Training model with 400 hidden variables
# Epoch     0, train loss 1.873786, train error 67.35,  test loss 1.792702, test error 70.50
# Epoch   100, train loss 0.011702, train error 0.00,  test loss 1.750359, test error 45.70
# Epoch   200, train loss 0.004164, train error 0.00,  test loss 1.921041, test error 45.85
# Epoch   300, train loss 0.002412, train error 0.00,  test loss 2.018753, test error 45.80
# Epoch   400, train loss 0.001662, train error 0.00,  test loss 2.086303, test error 45.80
# Epoch   500, train loss 0.001253, train error 0.00,  test loss 2.138824, test error 45.90
# Epoch   600, train loss 0.000998, train error 0.00,  test loss 2.181801, test error 45.78
# Epoch   700, train loss 0.000824, train error 0.00,  test loss 2.216882, test error 45.78
# Epoch   800, train loss 0.000700, train error 0.00,  test loss 2.247802, test error 45.83
# Epoch   900, train loss 0.000606, train error 0.00,  test loss 2.275152, test error 45.72

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
